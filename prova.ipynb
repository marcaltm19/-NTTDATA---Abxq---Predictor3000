# %%
import pandas as pd

# %%
data = pd.read_excel("consumo_material_clean.xlsx")

# %%
data.head(3)
# Out:
#    CODIGO FECHAPEDIDO      NUMERO REFERENCIA  CANTIDADCOMPRA  \
# 0  E99808    01/01/23  1595724/23   178567.1              60
# 1  B41691    01/02/16    72714/16     400403              40
# 2  E64543    01/02/16    71961/16     403770              20
#
#    UNIDADESCONSUMOCONTENIDAS      PRECIO  IMPORTELINEA    TIPOCOMPRA   ORIGEN  \
# 0                         10   62.590000    375.540000  Compra menor   1-2-60
# 1                         10  102.803729    411.214916  Compra menor   0-10-1
# 2                          5   12.100000     48.400000  Compra menor  0-4-111
#
#            TGL                                           PRODUCTO
# 0     TRANSITO        APOSITO DE FIBRAS DE POLIACRILATO C/PLATA-3
# 1  ALMACENABLE  SOLUCION P/ LIMPIEZA Y DESCONTAMINACION DE HER...
# 2     TRANSITO                  APOSITO DE HIDROFIBRA  / CINTA-18

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15698 entries, 0 to 15697
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CODIGO                     15698 non-null  object
#  1   FECHAPEDIDO                15698 non-null  object
#  2   NUMERO                     15698 non-null  object
#  3   REFERENCIA                 15698 non-null  object
#  4   CANTIDADCOMPRA             15698 non-null  int64
#  5   UNIDADESCONSUMOCONTENIDAS  15698 non-null  int64
#  6   PRECIO                     15698 non-null  float64
#  7   IMPORTELINEA               15698 non-null  float64
#  8   TIPOCOMPRA                 15698 non-null  object
#  9   ORIGEN                     15698 non-null  object
#  10  TGL                        15595 non-null  object
#  11  PRODUCTO                   15698 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
data.head(1230)
# Out:
#       CODIGO FECHAPEDIDO      NUMERO REFERENCIA  CANTIDADCOMPRA  \
# 0     E99808    01/01/23  1595724/23   178567.1              60
# 1     B41691    01/02/16    72714/16     400403              40
# 2     E64543    01/02/16    71961/16     403770              20
# 3     E65007    01/02/16    72773/16      20415             100
# 4     E64911    01/02/17    86159/17      20701             300
# ...      ...         ...         ...        ...             ...
# 1225  B40558    03/08/16   733670/16     400505              10
# 1226  E64932    03/08/16   733372/16      39001             100
# 1227  E65159    03/08/16   733607/16    281 421            2000
# 1228  E65201    03/08/16   732482/16       3760             120
# 1229  B41691    03/08/17   577016/17     400403              30
#
#       UNIDADESCONSUMOCONTENIDAS      PRECIO  IMPORTELINEA    TIPOCOMPRA  \
# 0                            10   62.590000    375.540000  Compra menor
# ...
